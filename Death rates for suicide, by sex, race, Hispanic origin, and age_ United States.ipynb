# %% [markdown]
# # Death rates for suicide, by sex, race, Hispanic origin, and age: United States
#
# Data on death rates for suicide, by selected population characteristics. Please refer to the PDF or Excel version of this table in the HUS 2019 Data Finder (https://www.cdc.gov/nchs/hus/contents2019.htm) for critical information about measures, definitions, and changes over time.
#
# SOURCE: NCHS, National Vital Statistics System (NVSS); Grove RD, Hetzel AM. Vital statistics rates in the United States, 1940–1960. National Center for Health Statistics. 1968; numerator data from NVSS annual public-use Mortality Files; denominator data from U.S. Census Bureau national population estimates; and Murphy SL, Xu JQ, Kochanek KD, Arias E, Tejada-Vera B. Deaths: Final data for 2018. National Vital Statistics Reports; vol 69 no 13. Hyattsville, MD: National Center for Health Statistics. 2021. Available from: https://www.cdc.gov/nchs/products/nvsr.htm. For more information on the National Vital Statistics System, see the corresponding Appendix entry at https://www.cdc.gov/nchs/data/hus/hus19-appendix-508.pdf.

# %% [markdown]
# ## Metadata
#
# {"@type": "dcat:Dataset", "accessLevel": "public", "accrualPeriodicity": "R/P1Y", "bureauCode": ["009:20"], "contactPoint": {"@type": "vcard:Contact", "fn": "National Center for Health Statistics", "hasEmail": "mailto:healthus@cdc.gov"}, "description": "Data on death rates for suicide, by selected population characteristics. Please refer to the PDF or Excel version of this table in the HUS 2019 Data Finder (https://www.cdc.gov/nchs/hus/contents2019.htm) for critical information about measures, definitions, and changes over time. \n\nSOURCE: NCHS, National  Vital Statistics System (NVSS); Grove RD, Hetzel AM. Vital statistics rates in the United States, 1940\u20131960. National Center for Health Statistics. 1968; numerator data from NVSS annual public-use Mortality Files; denominator data from U.S. Census Bureau national population estimates; and Murphy SL, Xu JQ, Kochanek KD, Arias E, Tejada-Vera B. Deaths: Final data for 2018. National Vital Statistics Reports; vol 69 no 13. Hyattsville, MD: National Center for Health Statistics. 2021. Available from: https://www.cdc.gov/nchs/products/nvsr.htm. For more information on the National Vital Statistics System, see the corresponding Appendix entry at https://www.cdc.gov/nchs/data/hus/hus19-appendix-508.pdf.", "distribution": [{"@type": "dcat:Distribution", "downloadURL": "https://data.cdc.gov/api/views/9j2v-jamp/rows.csv?accessType=DOWNLOAD", "mediaType": "text/csv"}, {"@type": "dcat:Distribution", "downloadURL": "https://data.cdc.gov/api/views/9j2v-jamp/rows.rdf?accessType=DOWNLOAD", "mediaType": "application/rdf+xml"}, {"@type": "dcat:Distribution", "downloadURL": "https://data.cdc.gov/api/views/9j2v-jamp/rows.json?accessType=DOWNLOAD", "mediaType": "application/json"}, {"@type": "dcat:Distribution", "downloadURL": "https://data.cdc.gov/api/views/9j2v-jamp/rows.xml?accessType=DOWNLOAD", "mediaType": "application/xml"}], "identifier": "https://data.cdc.gov/api/views/9j2v-jamp", "issued": "2021-05-14", "keyword": ["african americans", "age", "alaskan natives", "american natives", "asian continental ancestry group", "continental population groups", "death", "deaths", "european continental ancestry group", "health us", "hispanic americans", "injury", "mental health", "mortality", "sex", "suicide"], "landingPage": "https://www.cdc.gov/nchs/hus", "license": "https://www.usa.gov/government-works", "modified": "2022-04-27", "programCode": ["009:020"], "publisher": {"@type": "org:Organization", "name": "Centers for Disease Control and Prevention"}, "spatial": "United States", "temporal": "1950/2019", "theme": ["NCHS"], "title": "Death rates for suicide, by sex, race, Hispanic origin, and age: United States"}

# %% [markdown]
# ## Access & Use Information
#
# Public: This dataset is intended for public access and use.
#  License: See this page for license information.

# %% [markdown]
# ## Dates
#
# Metadata Created Date	April 21, 2022
# Metadata Updated Date	April 28, 2022
# Data Update Frequency	R/P1Y
# Metadata Source
# Data.jsonData.json Metadata
# Download Metadata
#
# Harvested from Healthdata.gov
#
# african-americans age alaskan-natives american-natives asian-continental-a... continental-populat... death deaths european-continenta... health-us hispanic-americans injury mental-health mortality sex suicide
#
# ## Additional Metadata
#
# Resource Type	Dataset
# Metadata Created Date	April 21, 2022
# Metadata Updated Date	April 28, 2022
# Publisher	Centers for Disease Control and Prevention
# Maintainer
# National Center for Health Statistics

# %%
#Importing all necessary library for data cleaning process

import pandas as pd

import numpy as np

# %%
#Loading data 

df = pd.read_csv("C:\\Users\\Ezeizu Vitalis\\OneDrive - Swansea University\\Swansea University Reading templates\\Python class\\Github worthy\\Death_rates_for_suicide__by_sex__race__Hispanic_origin__and_age__United_States.csv")

# %%
#To get the first 10 rows and the last 10 rows

df.head(10)
# Out:
#                  INDICATOR                                               UNIT  \
# 0  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 1  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 2  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 3  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 4  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 5  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 6  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 7  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 8  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 9  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
#
#    UNIT_NUM STUB_NAME  STUB_NAME_NUM   STUB_LABEL  STUB_LABEL_NUM  YEAR  \
# ...

# %%
df.tail(10)
# Out:
#                     INDICATOR                                           UNIT  \
# 6380  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6381  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6382  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6383  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6384  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6385  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6386  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6387  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6388  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6389  Death rates for suicide  Deaths per 100,000 resident population, crude
#
#       UNIT_NUM                                          STUB_NAME  \
# ...

# %% [markdown]
# ### Basic Information

# %%
#To get the rows and columns 

df.shape
# Out:
# (6390, 13)

# %%
# To describe the index

df.index
# Out:
# RangeIndex(start=0, stop=6390, step=1)

# %%
# To describe dataframe columns

df.columns
# Out:
# Index(['INDICATOR', 'UNIT', 'UNIT_NUM', 'STUB_NAME', 'STUB_NAME_NUM',
#        'STUB_LABEL', 'STUB_LABEL_NUM', 'YEAR', 'YEAR_NUM', 'AGE', 'AGE_NUM',
#        'ESTIMATE', 'FLAG'],
#       dtype='object')

# %%
# To get information about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6390 entries, 0 to 6389
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDICATOR       6390 non-null   object
#  1   UNIT            6390 non-null   object
#  2   UNIT_NUM        6390 non-null   int64
#  3   STUB_NAME       6390 non-null   object
#  4   STUB_NAME_NUM   6390 non-null   int64
#  5   STUB_LABEL      6390 non-null   object
#  6   STUB_LABEL_NUM  6390 non-null   float64
#  7   YEAR            6390 non-null   int64
#  8   YEAR_NUM        6390 non-null   int64
#  9   AGE             6390 non-null   object
#  10  AGE_NUM         6390 non-null   float64
#  11  ESTIMATE        5484 non-null   float64
#  12  FLAG            906 non-null    object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 649.1+ KB

# %%
#To get the number of non -NA values

df.count()
# Out:
# INDICATOR         6390
# UNIT              6390
# UNIT_NUM          6390
# STUB_NAME         6390
# STUB_NAME_NUM     6390
# STUB_LABEL        6390
# STUB_LABEL_NUM    6390
# YEAR              6390
# YEAR_NUM          6390
# AGE               6390
# AGE_NUM           6390
# ESTIMATE          5484
# FLAG               906
# dtype: int64

# %% [markdown]
# ### Summary

# %%
#Summary of the data

df.describe()
# Out:
#           UNIT_NUM  STUB_NAME_NUM  STUB_LABEL_NUM         YEAR     YEAR_NUM  \
# count  6390.000000    6390.000000     6390.000000  6390.000000  6390.000000
# mean      1.872926       4.621909        4.686775  1997.525822    22.692019
# std       0.333081       2.031777        1.829624    14.937451    12.286033
# min       1.000000       0.000000        0.000000  1950.000000     1.000000
# 25%       2.000000       3.000000        3.230000  1988.000000    12.000000
# 50%       2.000000       5.000000        5.125100  1999.000000    23.000000
# 75%       2.000000       6.000000        6.153000  2009.000000    33.000000
# max       2.000000      11.000000        7.235000  2018.000000    42.000000
#
#            AGE_NUM     ESTIMATE
# count  6390.000000  5484.000000
# mean      2.712207    13.709810
# std       1.932280    11.531805
# min       0.000000     0.300000
# 25%       0.000000     5.000000
# 50%       3.000000    10.500000
# 75%       4.100000    19.500000
# ...

# %% [markdown]
# # Data wrangling

# %% [markdown]
# The following are the necessary corrections for the dataset:
#
# 1) Drop the column FLAG, AGE NUM, YEAR NUM, STUB_LABEL_NUM, STUB_NAME_NUM, UNIT_NUM)
# 2) Standardize the AGE column
# 3) Split STUB_LABEL, UNIT
# 4) Fill in the null vlue for estimates.
# 5) Convert YEAR datatype to date datatype
# 6) Convert age to int

# %% [markdown]
# 1) Dropping the FLAG, AGE_NUM, YEAR_NUM, STUB_LABEL_NUM, STUB_NAME_NUM, UNIT_NUM columns

# %%
# To copy the dataset

db = df.copy()

# %%
# Droping columns

db.drop(columns = ["FLAG", "AGE_NUM", "YEAR_NUM", "STUB_LABEL_NUM", "UNIT_NUM"], axis = 1, inplace = True)

# %%
db.drop(columns = "STUB_NAME_NUM", axis = 1, inplace = True)

# %%
db.head(10)
# Out:
#                  INDICATOR                                               UNIT  \
# 0  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 1  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 2  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 3  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 4  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 5  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 6  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 7  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 8  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 9  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
#
#   STUB_NAME   STUB_LABEL  YEAR       AGE  ESTIMATE
# 0     Total  All persons  1950  All ages      13.2
# ...

# %%
db.tail(10)
# Out:
#                     INDICATOR                                           UNIT  \
# 6380  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6381  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6382  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6383  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6384  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6385  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6386  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6387  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6388  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6389  Death rates for suicide  Deaths per 100,000 resident population, crude
#
#                                               STUB_NAME  \
# 6380  Sex, age and race and Hispanic origin (Single ...
# ...

# %%
db["STUB_LABEL"].value_counts()
# Out:
# Female: Black or African American: 65 years and over                                            45
# Female: Black or African American: 45-64 years                                                  45
# Male: Black or African American: 45-64 years                                                    45
# Male: Black or African American: 65 years and over                                              45
# Female: Black or African American: 15-24 years                                                  43
#                                                                                                 ..
# Male: Not Hispanic or Latino: Native Hawaiian or Other Pacific Islander: 15-24 years             1
# Male: Not Hispanic or Latino: Asian: 65 years and over                                           1
# Male: Not Hispanic or Latino: Asian: 45-64 years                                                 1
# ...

# %% [markdown]
# 2) Standardize the AGE column

# %%
# getting the unique values in AGE column

db["AGE"].value_counts()
# Out:
# All ages             1624
# 15-24 years           812
# 25-44 years           812
# 45-64 years           812
# 65 years and over     812
# 65-74 years           212
# 75-84 years           212
# 85 years and over     212
# 10-14 years           126
# 15-19 years           126
# 20-24 years           126
# 25-34 years           126
# 35-44 years           126
# 45-54 years           126
# 55-64 years           126
# Name: AGE, dtype: int64

# %%
#To filter and drop the "All ages" in the AGE column

for x in db.index:
    
    if db.loc[x, "AGE"] == "All ages":
        
        db.drop(x, inplace = True)
        
db.head(5)
# Out:
#                    INDICATOR                                           UNIT  \
# 854  Death rates for suicide  Deaths per 100,000 resident population, crude
# 855  Death rates for suicide  Deaths per 100,000 resident population, crude
# 856  Death rates for suicide  Deaths per 100,000 resident population, crude
# 857  Death rates for suicide  Deaths per 100,000 resident population, crude
# 858  Death rates for suicide  Deaths per 100,000 resident population, crude
#
#     STUB_NAME   STUB_LABEL  YEAR          AGE  ESTIMATE
# 854       Age  10-14 years  1950  10-14 years       0.3
# 855       Age  10-14 years  1960  10-14 years       0.5
# 856       Age  10-14 years  1970  10-14 years       0.6
# 857       Age  10-14 years  1980  10-14 years       0.8
# 858       Age  10-14 years  1981  10-14 years       0.9

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4766 entries, 854 to 6389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   INDICATOR   4766 non-null   object
#  1   UNIT        4766 non-null   object
#  2   STUB_NAME   4766 non-null   object
#  3   STUB_LABEL  4766 non-null   object
#  4   YEAR        4766 non-null   int64
#  5   AGE         4766 non-null   object
#  6   ESTIMATE    4062 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 426.9+ KB

# %%
db.head(20)
# Out:
#                    INDICATOR                                           UNIT  \
# 854  Death rates for suicide  Deaths per 100,000 resident population, crude
# 855  Death rates for suicide  Deaths per 100,000 resident population, crude
# 856  Death rates for suicide  Deaths per 100,000 resident population, crude
# 857  Death rates for suicide  Deaths per 100,000 resident population, crude
# 858  Death rates for suicide  Deaths per 100,000 resident population, crude
# 859  Death rates for suicide  Deaths per 100,000 resident population, crude
# 860  Death rates for suicide  Deaths per 100,000 resident population, crude
# 861  Death rates for suicide  Deaths per 100,000 resident population, crude
# 862  Death rates for suicide  Deaths per 100,000 resident population, crude
# 863  Death rates for suicide  Deaths per 100,000 resident population, crude
# 864  Death rates for suicide  Deaths per 100,000 resident population, crude
# ...

# %%
db["AGE"].value_counts()
# Out:
# 15-24 years          812
# 25-44 years          812
# 45-64 years          812
# 65 years and over    812
# 65-74 years          212
# 75-84 years          212
# 85 years and over    212
# 10-14 years          126
# 15-19 years          126
# 20-24 years          126
# 25-34 years          126
# 35-44 years          126
# 45-54 years          126
# 55-64 years          126
# Name: AGE, dtype: int64

# %%
# Reseting the index

db.reset_index(drop=True)
# Out:
#                     INDICATOR                                           UNIT  \
# 0     Death rates for suicide  Deaths per 100,000 resident population, crude
# 1     Death rates for suicide  Deaths per 100,000 resident population, crude
# 2     Death rates for suicide  Deaths per 100,000 resident population, crude
# 3     Death rates for suicide  Deaths per 100,000 resident population, crude
# 4     Death rates for suicide  Deaths per 100,000 resident population, crude
# ...                       ...                                            ...
# 4761  Death rates for suicide  Deaths per 100,000 resident population, crude
# 4762  Death rates for suicide  Deaths per 100,000 resident population, crude
# 4763  Death rates for suicide  Deaths per 100,000 resident population, crude
# 4764  Death rates for suicide  Deaths per 100,000 resident population, crude
# 4765  Death rates for suicide  Deaths per 100,000 resident population, crude
#
# ...

# %%
# Replacing "65 and over" with "65-84" and "85 and over" with "85-100"

db["AGE"] = db["AGE"].str.replace("65 years and over", "65-84")

# %%
db["AGE"] = db["AGE"].str.replace("85 years and over", "85-100")

# %%
# Confirming changes

db["AGE"].value_counts()
# Out:
# 15-24 years    812
# 25-44 years    812
# 45-64 years    812
# 65-84          812
# 65-74 years    212
# 75-84 years    212
# 85-100         212
# 10-14 years    126
# 15-19 years    126
# 20-24 years    126
# 25-34 years    126
# 35-44 years    126
# 45-54 years    126
# 55-64 years    126
# Name: AGE, dtype: int64

# %%
# Removing the "years" from the age dataset

db[["Age Range", "year"]] = db["AGE"].str.split(" ", 2, expand = True)
# Out:
# C:\Users\Ezeizu Vitalis\AppData\Local\Temp\ipykernel_11068\380884911.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   db[["Age Range", "year"]] = db["AGE"].str.split(" ", 2, expand = True)

# %%
#Checking for changes

db.head(5)
# Out:
#                    INDICATOR                                           UNIT  \
# 854  Death rates for suicide  Deaths per 100,000 resident population, crude
# 855  Death rates for suicide  Deaths per 100,000 resident population, crude
# 856  Death rates for suicide  Deaths per 100,000 resident population, crude
# 857  Death rates for suicide  Deaths per 100,000 resident population, crude
# 858  Death rates for suicide  Deaths per 100,000 resident population, crude
#
#     STUB_NAME   STUB_LABEL  YEAR          AGE  ESTIMATE Age Range   year
# 854       Age  10-14 years  1950  10-14 years       0.3     10-14  years
# 855       Age  10-14 years  1960  10-14 years       0.5     10-14  years
# 856       Age  10-14 years  1970  10-14 years       0.6     10-14  years
# 857       Age  10-14 years  1980  10-14 years       0.8     10-14  years
# 858       Age  10-14 years  1981  10-14 years       0.9     10-14  years

# %%
# Dropping the "AGE" and "year" column

db.drop(columns= ["year", "AGE"], axis = 1, inplace = True)

# %%
# Confirming changes

db.head(10)
# Out:
#                    INDICATOR                                           UNIT  \
# 854  Death rates for suicide  Deaths per 100,000 resident population, crude
# 855  Death rates for suicide  Deaths per 100,000 resident population, crude
# 856  Death rates for suicide  Deaths per 100,000 resident population, crude
# 857  Death rates for suicide  Deaths per 100,000 resident population, crude
# 858  Death rates for suicide  Deaths per 100,000 resident population, crude
# 859  Death rates for suicide  Deaths per 100,000 resident population, crude
# 860  Death rates for suicide  Deaths per 100,000 resident population, crude
# 861  Death rates for suicide  Deaths per 100,000 resident population, crude
# 862  Death rates for suicide  Deaths per 100,000 resident population, crude
# 863  Death rates for suicide  Deaths per 100,000 resident population, crude
#
#     STUB_NAME   STUB_LABEL  YEAR  ESTIMATE Age Range
# 854       Age  10-14 years  1950       0.3     10-14
# ...

# %%
#Checking unique value for age

db["Age Range"].value_counts()
# Out:
# 15-24     812
# 25-44     812
# 45-64     812
# 65-84     812
# 65-74     212
# 75-84     212
# 85-100    212
# 10-14     126
# 15-19     126
# 20-24     126
# 25-34     126
# 35-44     126
# 45-54     126
# 55-64     126
# Name: Age Range, dtype: int64

# %% [markdown]
# Checking for Null values in the "Estimate column"

# %%
#Checking null values

db["ESTIMATE"].isnull().sum()
# Out:
# 704

# %%
# Filling in the missing values using the mean of the column

db.fillna(db["ESTIMATE"].mean(), inplace = True)

# %%
#Confirming changes

db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4766 entries, 854 to 6389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   INDICATOR   4766 non-null   object
#  1   UNIT        4766 non-null   object
#  2   STUB_NAME   4766 non-null   object
#  3   STUB_LABEL  4766 non-null   object
#  4   YEAR        4766 non-null   int64
#  5   ESTIMATE    4766 non-null   float64
#  6   Age Range   4766 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 426.9+ KB

# %%
#Checking the first 10 rows

db.head(10)
# Out:
#                    INDICATOR                                           UNIT  \
# 854  Death rates for suicide  Deaths per 100,000 resident population, crude
# 855  Death rates for suicide  Deaths per 100,000 resident population, crude
# 856  Death rates for suicide  Deaths per 100,000 resident population, crude
# 857  Death rates for suicide  Deaths per 100,000 resident population, crude
# 858  Death rates for suicide  Deaths per 100,000 resident population, crude
# 859  Death rates for suicide  Deaths per 100,000 resident population, crude
# 860  Death rates for suicide  Deaths per 100,000 resident population, crude
# 861  Death rates for suicide  Deaths per 100,000 resident population, crude
# 862  Death rates for suicide  Deaths per 100,000 resident population, crude
# 863  Death rates for suicide  Deaths per 100,000 resident population, crude
#
#     STUB_NAME   STUB_LABEL  YEAR  ESTIMATE Age Range
# 854       Age  10-14 years  1950       0.3     10-14
# ...

# %% [markdown]
# Standardizing the YEAR column

# %%
#Changing the data type 

db["YEAR"] = pd.to_datetime(db["YEAR"])

# %%
#Checking for changes

db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4766 entries, 854 to 6389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   INDICATOR   4766 non-null   object
#  1   UNIT        4766 non-null   object
#  2   STUB_NAME   4766 non-null   object
#  3   STUB_LABEL  4766 non-null   object
#  4   YEAR        4766 non-null   datetime64[ns]
#  5   ESTIMATE    4766 non-null   float64
#  6   Age Range   4766 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 426.9+ KB

# %% [markdown]
# ### SAVING THE DOCUMENT

# %%
db.to_csv ("Death_rates_for_suicide__by_sex__race__Hispanic_origin__and_age__United_States_clean.csv", index = False)

# %% [markdown]
# ### Downloading the file from jupyter notebook

# %%
from IPython.display import FileLink

# %%
FileLink("Death_rates_for_suicide__by_sex__race__Hispanic_origin__and_age__United_States_clean.csv")
# Out:
# C:\Users\Ezeizu Vitalis\Death_rates_for_suicide__by_sex__race__Hispanic_origin__and_age__United_States_clean.csv
